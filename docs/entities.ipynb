# %% [markdown]
# Any
# ABI of Any
#     Bit
#         bitlength: 1
#         aligment: 1
#
#     Byte: 8 Bit
#         bitlength: 8
#         aligment: 8
#
# x86_64
# ABI of x86_64
#     extends from ABI of Any
#     Word
#         64 Bit
#         aligment: 64
